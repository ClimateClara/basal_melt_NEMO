# %%
"""
Compare results of NEMO experiments to identfy PISCES problem

"""

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
# %matplotlib qt5
# Out:
# QStandardPaths: error creating runtime directory '/run/user/2784' (Permission denied)

# %% [markdown]
# Declare paths

# %%
inputpath = '/data/cburgard/EVAL_IPSLCM/'
inputpath_domain_cfg = '/data/cburgard/PREPARE_FORCING/PREPARE_PRESCRIBED_MELT/interim/'

# %%
MBG_05_median = xr.open_dataset(inputpath + 'findprob-opencav05_19480101_19481231_1Y_ptrc_T.nc').quantile(0.999, ['x','y','deptht'])
MBG_06_median = xr.open_dataset(inputpath + 'findprob-opencav06_19480101_19481231_1Y_ptrc_T.nc').quantile(0.999, ['x','y','deptht'])
OCE_05_median = xr.open_dataset(inputpath + 'findprob-opencav05_19480101_19481231_1Y_grid_T.nc').quantile(0.999, ['x','y','deptht'])
OCE_06_median = xr.open_dataset(inputpath + 'findprob-opencav06_19480101_19481231_1Y_grid_T.nc').quantile(0.999, ['x','y','deptht'])
# Out:
# /home/cburgard/.local/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1577: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# /home/cburgard/.local/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1577: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,

# %%
MBG_06.max()
# Out:
# <xarray.Dataset>
# Dimensions:               (nvertex: 4, axis_nbounds: 2, time_counter: 1)
# Coordinates:
#     time_centered         (time_counter) object ...
#   * time_counter          (time_counter) object 1948-07-02 12:00:00
#     quantile              float64 0.99
# Dimensions without coordinates: nvertex, axis_nbounds
# Data variables: (12/31)
#     bounds_nav_lon        (nvertex) float64 176.0 176.0 176.0 176.0
#     bounds_nav_lat        (nvertex) float64 81.18 81.18 81.49 81.49
#     area                  float64 1.118e+10
#     deptht_bounds         (axis_nbounds) float64 5.649e+03 5.853e+03
#     time_centered_bounds  (time_counter, axis_nbounds) object ...
#     time_counter_bounds   (time_counter, axis_nbounds) object ...
#     ...                    ...
#     GSi                   (time_counter) float64 0.0668
#     NFe                   (time_counter) float64 4.274e-05
#     NCHL                  (time_counter) float64 0.2321
#     DCHL                  (time_counter) float64 0.4031
#     NO3                   (time_counter) float64 42.08
#     NH4                   (time_counter) float64 0.2962

# %%
MBG_05 = xr.open_dataset(inputpath + 'findprob-opencav05_19480101_19481231_1Y_ptrc_T.nc').sel(y=slice(0,100))
MBG_06 = xr.open_dataset(inputpath + 'findprob-opencav06_19480101_19481231_1Y_ptrc_T.nc').sel(y=slice(0,100))
OCE_05 = xr.open_dataset(inputpath + 'findprob-opencav05_19480101_19481231_1Y_grid_T.nc').sel(y=slice(0,100))
OCE_06 = xr.open_dataset(inputpath + 'findprob-opencav06_19480101_19481231_1Y_grid_T.nc').sel(y=slice(0,100))

# %%
domain_cfg = xr.open_dataset(inputpath_domain_cfg + 'eORCA1.4.3_OpenSeas_Open6largestISF_ModStraights_domain_cfg.nc').sel(y=slice(0,100))

# %%
OCE_05
# Out:
# <xarray.Dataset>
# Dimensions:               (y: 100, x: 360, nvertex: 4, deptht: 75,
#                            axis_nbounds: 2, time_counter: 1)
# Coordinates:
#     nav_lat               (y, x) float32 ...
#     nav_lon               (y, x) float32 ...
#   * deptht                (deptht) float32 0.5058 1.556 ... 5.698e+03 5.902e+03
#     time_centered         (time_counter) object ...
#   * time_counter          (time_counter) object 1948-07-02 12:00:00
# Dimensions without coordinates: y, x, nvertex, axis_nbounds
# Data variables: (12/55)
#     bounds_nav_lon        (y, x, nvertex) float32 ...
#     bounds_nav_lat        (y, x, nvertex) float32 ...
#     area                  (y, x) float32 ...
#     deptht_bounds         (deptht, axis_nbounds) float32 ...
#     time_centered_bounds  (time_counter, axis_nbounds) object ...
#     time_counter_bounds   (time_counter, axis_nbounds) object ...
#     ...                    ...
#     vfxsub                (time_counter, y, x) float32 ...
#     snow_ao_cea           (time_counter, y, x) float32 ...
#     snow_ai_cea           (time_counter, y, x) float32 ...
#     evap_ao_cea           (time_counter, y, x) float32 ...
#     subl_ai_cea           (time_counter, y, x) float32 ...
#     sosflxdo              (time_counter, y, x) float32 ...
# Attributes:
#     name:         findprob-opencav05_1y_grid_T
#     description:  ocean T grid variables
#     title:        ocean T grid variables
#     Conventions:  CF-1.6
#     timeStamp:    2025-Jun-03 11:30:05 GMT
#     uuid:         1f859663-23d1-4b56-bceb-a763661a2c4f
#     LongName:     ORCA1_SI3_PISCES NEMO configuration
#     history:      Tue Jun  3 13:41:12 2025: ncrcat -C --buffer_size 838860800...
#     NCO:          netCDF Operators version 5.0.1 (Homepage = http://nco.sf.ne...

# %%
vvar = 'PO4'

plt.figure()
MBG_05[vvar].max('deptht').plot(vmax=MBG_05_median[vvar])
plt.title(vvar+'05')

plt.figure()
MBG_06[vvar].max('deptht').plot(vmax=MBG_06_median[vvar])
plt.title(vvar+'06')

plt.figure()
plt.scatter(MBG_05[vvar],MBG_06[vvar])
plt.scatter(MBG_05_median[vvar],MBG_06_median[vvar],color='red')

# %%
vvar = 'PO4'
plt.scatter(OCE_05['iceshelf'], MBG_06[vvar].max('deptht'))

# %%
vvar = 'PO4'
plt.scatter((domain_cfg['isf_draft'] - domain_cfg['bathy_metry']),MBG_06[vvar].max('deptht'))

# %%
plt.scatter(OCE_05['so'],OCE_06['so'],alpha=0.1)

# %%
MBG_05[vvar]
# Out:
# <xarray.DataArray 'PO4' (time_counter: 1, deptht: 75, y: 100, x: 360)>
# array([[[[0.      , ...,      nan],
#          ...,
#          [1.972669, ..., 1.927278]],
#
#         ...,
#
#         [[0.      , ...,      nan],
#          ...,
#          [0.      , ..., 0.      ]]]], dtype=float32)
# Coordinates:
#     nav_lat        (y, x) float32 ...
#     nav_lon        (y, x) float32 ...
#   * deptht         (deptht) float32 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#     time_centered  (time_counter) object ...
#   * time_counter   (time_counter) object 1948-07-02 12:00:00
# Dimensions without coordinates: y, x
# Attributes:
#     long_name:           Phosphate Concentration
#     units:               mmol/m3
#     online_operation:    average
#     interval_operation:  1 yr
#     interval_write:      1 yr
#     cell_methods:        time: mean time_counter: mean
#     cell_measures:       area: area
